# %% [markdown]
# # Plot Random Walk
#
# Allow visualization of coordinate mapping

# %%
from randomwalk import RandomWalk

# %%
walk = RandomWalk(size=100)

# %%
import matplotlib.pyplot as plt
plt.plot(walk.coordinates)
